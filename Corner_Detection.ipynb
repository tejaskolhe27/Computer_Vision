# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
img =  cv2.imread('images/draw.png')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray = np.float32(gray)

#detect corners
#Parameters:src,blocksize,ksize,k
dst  = cv2.cornerHarris(gray,2,3,0.02)

#dilate corner image to enhance corner Points
dst = cv2.dilate(dst,None)

# %%
plt.figure(figsize=(16,9))
plt.subplot(1,2,1)
plt.title("Original Image")
plt.imshow(img)

plt.subplot(1,2,2)
plt.title("Dilate corner Image")
plt.imshow(dst,cmap = 'gray')
plt.show()

# %%
img =  cv2.imread('images/circle.png')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray = np.float32(gray)

#detect corners
#Parameters:src,blocksize,ksize,k
dst  = cv2.cornerHarris(gray,2,3,0.02)

#dilate cornr image to enhance corner Points
dst = cv2.dilate(dst,None)

# %%
plt.figure(figsize=(16,9))
plt.subplot(1,2,1)
plt.title("Original Image")
plt.imshow(img)

plt.subplot(1,2,2)
plt.title("Dilate corner Image")
plt.imshow(dst,cmap = 'gray')
plt.show()
